# %% [markdown]
# # Time Series Bitcoin Historical Data
#
# Bitcoin - USD data with 1-day intervals from Yahoo Finance (https://finance.yahoo.com/quote/BTC-USD/).
#
# ---
#
# **Training Accuracy (%)**
#
# - loss: 0.41
# - mae: 4.48
#
# **Validation Accuracy (%)**
#
# - loss: 0.41
# - mae: 4.75
#
# The training process takes ***7m 25s*** using ***500 epochs***

# %%
# install library needed
# !pip install yfinance
# Out:
# Collecting yfinance
#   Downloading https://files.pythonhosted.org/packages/79/bd/d64719da8f5367f4d8b16e83507fa1d90942f433f748a4cf3ed7aa515d14/yfinance-0.1.63.tar.gz
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.1.5)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.19.5)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.7/dist-packages (from yfinance) (2.23.0)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from yfinance) (0.0.9)
# Collecting lxml>=4.5.1
#   Downloading https://files.pythonhosted.org/packages/30/c0/d0526314971fc661b083ab135747dc68446a3022686da8c16d25fcf6ef07/lxml-4.6.3-cp37-cp37m-manylinux2014_x86_64.whl (6.3MB)
#      |████████████████████████████████| 6.3MB 9.1MB/s
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24->yfinance) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24->yfinance) (2018.9)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20->yfinance) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20->yfinance) (2021.5.30)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20->yfinance) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20->yfinance) (3.0.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.24->yfinance) (1.15.0)
# Building wheels for collected packages: yfinance
#   Building wheel for yfinance (setup.py) ... done
#   Created wheel for yfinance: filename=yfinance-0.1.63-py2.py3-none-any.whl size=23919 sha256=5da3c9c1e662bc2b54af8b1c7c6e329e3e759079d39693369e9fdea850477f5b
#   Stored in directory: /root/.cache/pip/wheels/fe/a0/79/b73d4a0c535b421b88fc7b393936b371fabbfeaf979eca4050
# Successfully built yfinance
# Installing collected packages: lxml, yfinance
#   Found existing installation: lxml 4.2.6
#     Uninstalling lxml-4.2.6:
#       Successfully uninstalled lxml-4.2.6
# Successfully installed lxml-4.6.3 yfinance-0.1.63

# %%
# import library needed
from tensorflow import keras
from tensorflow import data as td
from tensorflow import expand_dims
from keras.optimizers import Adam, SGD
from keras.models import Sequential, Model, load_model
from keras.layers import Input, LSTM, CuDNNLSTM, Bidirectional, SpatialDropout1D, Conv1D, Dropout, Dense, Activation, Lambda
from keras.callbacks import ModelCheckpoint, EarlyStopping, CSVLogger
from keras.losses import Huber
from keras.utils.vis_utils import plot_model

import yfinance as yf
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from google.colab import drive
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sn
import numpy as np
import pandas as pd

import os
import io
import uuid
import time
import datetime
import requests
import warnings
from IPython.display import Markdown
from IPython.display import display
from slugify import slugify

# %%
# ignore the unwanted warning messages
warnings.filterwarnings('ignore')

# %%
# Define base path for worksheet
BASE_PATH = '/content/drive/MyDrive/Playground/BitcoinPrice'
# No. of number of samples that will be propagated through the network
BATCH_SIZE=100
# Window Size
WINDOW_SIZE=50
# Learning rate
LEARNING_RATE=1e-8
# Momentum
MOMENTUM=0.9
# Number of iterations
EPOCH=500
# Set the train dropout
DROPOUT=0.2

# %%
# mount our google drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### Data Gatering

# %%
def yf_downloader(ticker, period="max", interval="1d"):
  '''
  ticker: ticker code
  period: 1d,5d,1mo,3mo,6mo,1y,2y,5y,10y,ytd,max
  interval: 1m,2m,5m,15m,30m,60m,90m,1h,1d,5d,1wk,1mo,3mo
  '''
  # download dataframe
  try:
    data = pdr.get_data_yahoo("BTC-USD", period=period, interval=interval)
  except Exception as e:
    print("Downloading data from yahoo finance error: {}".format(e))

  # dataset save path and filename
  dataset_path = os.path.join(BASE_PATH, ticker + '-' + period + '-' + interval + '.csv')
  # save data into csv for future usage
  data.to_csv(dataset_path)

  print("Successfully download dataset and saved at: {}".format(dataset_path))

# %%
# download the dataset
yf_downloader(ticker="BTC-USD")
# Out:
# [*********************100%***********************]  1 of 1 completed
# Successfully download dataset and saved at: /content/drive/MyDrive/Playground/BitcoinPrice/BTC-USD-max-1d.csv

# %% [markdown]
# ### Load Dataset

# %%
# load dataset
dataset = os.path.join(BASE_PATH, 'BTC-USD-max-1d.csv')
df = pd.read_csv(dataset, sep=',')
print('Dataset loaded ...')
# Out:
# Dataset loaded ...

# %% [markdown]
# ### Data Exploration

# %%
# sort data frame by date
df = df.sort_values('Date')
# check the result
df.head()
# Out:
#          Date        Open        High  ...       Close   Adj Close    Volume
# 0  2014-09-17  465.864014  468.174011  ...  457.334015  457.334015  21056800
# 1  2014-09-18  456.859985  456.859985  ...  424.440002  424.440002  34483200
# 2  2014-09-19  424.102997  427.834991  ...  394.795990  394.795990  37919700
# 3  2014-09-20  394.673004  423.295990  ...  408.903992  408.903992  36863600
# 4  2014-09-21  408.084991  412.425995  ...  398.821014  398.821014  26580100
#
# [5 rows x 7 columns]

# %%
# get total data
df.count()
# Out:
# Date         2485
# Open         2485
# High         2485
# Low          2485
# Close        2485
# Adj Close    2485
# Volume       2485
# dtype: int64

# %%
# simple metric study
df['Close'].describe()
# Out:
# count     2485.000000
# mean      8027.015138
# std      12040.024824
# min        178.102997
# 25%        531.385986
# 50%       4578.770020
# 75%       9303.629883
# max      63503.457031
# Name: Close, dtype: float64

# %%
# check null value
df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %% [markdown]
# For price I will only use the High and Low price. So, unused data will be droped.

# %%
df['Price'] = (df['Low']+df['High'])/2.0
df.drop(['Open','High','Low','Close','Adj Close','Volume'],axis=1, inplace=True)

df['Date'] = pd.to_datetime(df['Date'], format='%Y-%m-%d',errors='coerce')
df = df.set_index('Date')
df = df.dropna()

df.head()
# Out:
#                  Price
# Date
# 2014-09-17  460.298004
# 2014-09-18  434.981995
# 2014-09-19  406.183502
# 2014-09-20  406.589493
# 2014-09-21  402.803497

# %% [markdown]
# ### Data Visualization

# %%
plt.figure(figsize=(20,8))
plt.plot(df)
plt.title('Bitcoin price',fontsize=20)
plt.xlabel('year',fontsize=15)
plt.ylabel('price',fontsize=15)
plt.show()

# %% [markdown]
# ### Normalization
#
# By using MinMaxScaler, The price range is (0 ~ 1) now.

# %%
scaler = MinMaxScaler()
price = scaler.fit_transform(np.array(df['Price']).reshape(-1,1))
df['Price'] = price

# %% [markdown]
# ### Sliding Window and Data Spliting

# %%
# sliding window
# predict 1 data by using 50 datas.
X_l = []
y_l = []
N = len(df)
D = 50
for i in range(N-D-1):
    X_l.append(df.iloc[i:i+D])
    y_l.append(df.iloc[i+D])
    
X = np.array(X_l)
y = np.array(y_l)

print(X.shape, y.shape)
# Out:
# (2434, 50, 1) (2434, 1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=100)

# %% [markdown]
# ## Modeling

# %%
def ModelLSTM():
  model = Sequential()
  model.add(Conv1D(filters=128, kernel_size=5, strides=1, padding="causal", activation="relu", input_shape=(50, 1)))
  model.add(Dropout(rate=DROPOUT))
  model.add(LSTM(64, return_sequences=True))
  model.add(Dropout(rate=DROPOUT))
  model.add(LSTM(64, return_sequences=True))
  model.add(Dense(units=32, activation="relu"))
  model.add(Dense(units=16, activation="relu"))
  model.add(Dense(units=1))
  model.add(Lambda(lambda x: x * 400))

  optimizer = SGD(lr=LEARNING_RATE, momentum=MOMENTUM)
  losses = Huber()
  model.compile(optimizer=optimizer,
                loss=losses,
                metrics=['mae'])

  return model

# %%
# Visualize LSTM model
print(ModelLSTM().summary())
# Out:
# Model: "sequential_24"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_19 (Conv1D)           (None, 50, 128)           768
# _________________________________________________________________
# lstm_40 (LSTM)               (None, 50, 64)            49408
# _________________________________________________________________
# lstm_41 (LSTM)               (None, 50, 64)            33024
# _________________________________________________________________
# dense_20 (Dense)             (None, 50, 32)            2080
# _________________________________________________________________
# dense_21 (Dense)             (None, 50, 16)            528
# _________________________________________________________________
# dense_22 (Dense)             (None, 50, 1)             17
# _________________________________________________________________
# lambda_18 (Lambda)           (None, 50, 1)             0
# =================================================================
# Total params: 85,825
# Trainable params: 85,825
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ## Training

# %%
# Print in markdown format
def printmd(string):
    display(Markdown(string))

# Plot training loss and mae
def plot_training(history, title, save=True, save_path=os.path.join(BASE_PATH, 'visualization')):
    printmd("### Training Loss and MAE")
    
    acc = history.history['mae']
    val_acc = history.history['val_mae']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epoch_list = range(1, len(acc) + 1)
    
    plt.plot(loss, label='Training Loss')
    plt.plot(val_loss, label='Validation Loss')
    plt.legend(loc=0, fontsize='large')
    plt.xlabel("Epoch #")
    plt.ylabel("Loss")
    plt.show()
    
    if save is True:
        filename = slugify(title) + '_loss_model.png'
        plt.savefig(save_path + '/' + filename)

    plt.plot(acc, label='Training MAE')
    plt.plot(val_acc, label='Validation MAE')
    plt.legend(loc=4, fontsize='large')
    plt.xlabel("Epoch #")
    plt.ylabel("MAE")
    plt.show()
    
    if save is True:
        filename = slugify(title) + '_acc_model.png'
        plt.savefig(save_path + '/' + filename)

# Evaluate model, confusion matrix and classification report
def model_evaluation(title, model, x_train, x_test, y_train, y_test, save=True, save_path=os.path.join(BASE_PATH, 'visualization')):
    printmd('### Training Accuracy')
    loss, mae = model.evaluate(x_train, y_train, verbose=1)

    print("loss: %.2f" % (loss*100))
    print("mae: %.2f" % (mae*100))
    
    printmd('### Validation Accuracy')
    loss, mae = model.evaluate(x_test, y_test, verbose=1)

    print("loss: %.2f" % (loss*100))
    print("mae: %.2f" % (mae*100))

# %%
# Adding callbacks
train_id = 'LSTM-' + str(uuid.uuid1())
best_model = os.path.join(BASE_PATH, 'model/best_model-' + train_id + '.h5')
last_model = os.path.join(BASE_PATH, 'model/last_model-' + train_id + '.h5')
csv_log = os.path.join(BASE_PATH, 'monitor/logs-' + train_id + '.h5')

ES = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)
MC = ModelCheckpoint(best_model, monitor='val_mae', mode='min', save_best_only=True, verbose=1)
CSVL = CSVLogger(csv_log, separator=",", append=True)

callbacks = [MC, ES, CSVL]

# %%
# Training start time
start_time = time.time()

print("Training strated with Train ID: {}".format(train_id))

model = ModelLSTM()
history = model.fit(X_train, y_train,
                  validation_data=(X_test, y_test),
                  epochs=EPOCH,
                  verbose=1,
                  callbacks=callbacks)

# Training complete
time_elapsed = time.time() - start_time
# Save last model
model.save(last_model)

print("=" * 30)
print("Training Finished, took {:.0f}m {:.0f}s".format(time_elapsed // 60, time_elapsed % 60))
print("Best model:", best_model)
print("Last model:", last_model)
# Out:
# Training strated with Train ID: LSTM-afad8770-e22b-11eb-92de-0242ac1c0002
# Epoch 1/500
# 61/61 [==============================] - 5s 26ms/step - loss: 0.3897 - mae: 0.6453 - val_loss: 0.3354 - val_mae: 0.5942
#
# Epoch 00001: val_mae improved from inf to 0.59418, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 2/500
# 61/61 [==============================] - 1s 10ms/step - loss: 0.2544 - mae: 0.5016 - val_loss: 0.3096 - val_mae: 0.5543
#
# Epoch 00002: val_mae improved from 0.59418 to 0.55426, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 3/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.2443 - mae: 0.4768 - val_loss: 0.2929 - val_mae: 0.5181
#
# Epoch 00003: val_mae improved from 0.55426 to 0.51811, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 4/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.2617 - mae: 0.4794 - val_loss: 0.2802 - val_mae: 0.4851
#
# Epoch 00004: val_mae improved from 0.51811 to 0.48506, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 5/500
# 61/61 [==============================] - 1s 10ms/step - loss: 0.2203 - mae: 0.4147 - val_loss: 0.2699 - val_mae: 0.4574
#
# Epoch 00005: val_mae improved from 0.48506 to 0.45739, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 6/500
# 61/61 [==============================] - 1s 10ms/step - loss: 0.2073 - mae: 0.3858 - val_loss: 0.2611 - val_mae: 0.4361
#
# Epoch 00006: val_mae improved from 0.45739 to 0.43613, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 7/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.1849 - mae: 0.3465 - val_loss: 0.2536 - val_mae: 0.4182
#
# Epoch 00007: val_mae improved from 0.43613 to 0.41820, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 8/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.1999 - mae: 0.3554 - val_loss: 0.2471 - val_mae: 0.4027
#
# Epoch 00008: val_mae improved from 0.41820 to 0.40266, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 9/500
# 61/61 [==============================] - 1s 12ms/step - loss: 0.2051 - mae: 0.3561 - val_loss: 0.2411 - val_mae: 0.3903
#
# Epoch 00009: val_mae improved from 0.40266 to 0.39032, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 10/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.2125 - mae: 0.3563 - val_loss: 0.2359 - val_mae: 0.3792
#
# Epoch 00010: val_mae improved from 0.39032 to 0.37924, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 11/500
# 61/61 [==============================] - 1s 10ms/step - loss: 0.1716 - mae: 0.3061 - val_loss: 0.2306 - val_mae: 0.3720
#
# Epoch 00011: val_mae improved from 0.37924 to 0.37198, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 12/500
# 61/61 [==============================] - 1s 10ms/step - loss: 0.1813 - mae: 0.3177 - val_loss: 0.2255 - val_mae: 0.3649
#
# Epoch 00012: val_mae improved from 0.37198 to 0.36495, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 13/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.1788 - mae: 0.3135 - val_loss: 0.2205 - val_mae: 0.3595
#
# Epoch 00013: val_mae improved from 0.36495 to 0.35953, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 14/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.1596 - mae: 0.2930 - val_loss: 0.2155 - val_mae: 0.3538
#
# Epoch 00014: val_mae improved from 0.35953 to 0.35383, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 15/500
# 61/61 [==============================] - 1s 10ms/step - loss: 0.1798 - mae: 0.3160 - val_loss: 0.2108 - val_mae: 0.3476
#
# Epoch 00015: val_mae improved from 0.35383 to 0.34764, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 16/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.1800 - mae: 0.3168 - val_loss: 0.2062 - val_mae: 0.3420
#
# Epoch 00016: val_mae improved from 0.34764 to 0.34197, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 17/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.1504 - mae: 0.2764 - val_loss: 0.2018 - val_mae: 0.3363
#
# Epoch 00017: val_mae improved from 0.34197 to 0.33627, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 18/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.1642 - mae: 0.2939 - val_loss: 0.1975 - val_mae: 0.3301
#
# Epoch 00018: val_mae improved from 0.33627 to 0.33011, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 19/500
# 61/61 [==============================] - 1s 10ms/step - loss: 0.1621 - mae: 0.2931 - val_loss: 0.1935 - val_mae: 0.3241
#
# Epoch 00019: val_mae improved from 0.33011 to 0.32409, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 20/500
# 61/61 [==============================] - 1s 10ms/step - loss: 0.1540 - mae: 0.2804 - val_loss: 0.1892 - val_mae: 0.3191
#
# Epoch 00020: val_mae improved from 0.32409 to 0.31909, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 21/500
# 61/61 [==============================] - 1s 10ms/step - loss: 0.1602 - mae: 0.2881 - val_loss: 0.1853 - val_mae: 0.3124
#
# Epoch 00021: val_mae improved from 0.31909 to 0.31240, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 22/500
# 61/61 [==============================] - 1s 10ms/step - loss: 0.1350 - mae: 0.2560 - val_loss: 0.1812 - val_mae: 0.3076
#
# Epoch 00022: val_mae improved from 0.31240 to 0.30763, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 23/500
# 61/61 [==============================] - 1s 10ms/step - loss: 0.1340 - mae: 0.2571 - val_loss: 0.1773 - val_mae: 0.3018
#
# Epoch 00023: val_mae improved from 0.30763 to 0.30176, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 24/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.1240 - mae: 0.2401 - val_loss: 0.1736 - val_mae: 0.2953
#
# Epoch 00024: val_mae improved from 0.30176 to 0.29533, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 25/500
# 61/61 [==============================] - 1s 10ms/step - loss: 0.1336 - mae: 0.2520 - val_loss: 0.1697 - val_mae: 0.2903
#
# Epoch 00025: val_mae improved from 0.29533 to 0.29030, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 26/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.1275 - mae: 0.2447 - val_loss: 0.1660 - val_mae: 0.2840
#
# Epoch 00026: val_mae improved from 0.29030 to 0.28404, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 27/500
# 61/61 [==============================] - 1s 10ms/step - loss: 0.1504 - mae: 0.2678 - val_loss: 0.1625 - val_mae: 0.2778
#
# Epoch 00027: val_mae improved from 0.28404 to 0.27784, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 28/500
# 61/61 [==============================] - 1s 10ms/step - loss: 0.1307 - mae: 0.2425 - val_loss: 0.1589 - val_mae: 0.2745
#
# Epoch 00028: val_mae improved from 0.27784 to 0.27448, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 29/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.1191 - mae: 0.2264 - val_loss: 0.1555 - val_mae: 0.2699
#
# Epoch 00029: val_mae improved from 0.27448 to 0.26988, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 30/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.1399 - mae: 0.2551 - val_loss: 0.1522 - val_mae: 0.2644
#
# Epoch 00030: val_mae improved from 0.26988 to 0.26443, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 31/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.1249 - mae: 0.2343 - val_loss: 0.1490 - val_mae: 0.2595
#
# Epoch 00031: val_mae improved from 0.26443 to 0.25947, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 32/500
# 61/61 [==============================] - 1s 10ms/step - loss: 0.1013 - mae: 0.2033 - val_loss: 0.1459 - val_mae: 0.2574
#
# Epoch 00032: val_mae improved from 0.25947 to 0.25745, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 33/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.1216 - mae: 0.2298 - val_loss: 0.1430 - val_mae: 0.2519
#
# Epoch 00033: val_mae improved from 0.25745 to 0.25186, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 34/500
# 61/61 [==============================] - 1s 10ms/step - loss: 0.0978 - mae: 0.1962 - val_loss: 0.1400 - val_mae: 0.2494
#
# Epoch 00034: val_mae improved from 0.25186 to 0.24942, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 35/500
# 61/61 [==============================] - 1s 10ms/step - loss: 0.1022 - mae: 0.2043 - val_loss: 0.1372 - val_mae: 0.2460
#
# Epoch 00035: val_mae improved from 0.24942 to 0.24603, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 36/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.1106 - mae: 0.2146 - val_loss: 0.1345 - val_mae: 0.2407
#
# Epoch 00036: val_mae improved from 0.24603 to 0.24069, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 37/500
# 61/61 [==============================] - 1s 10ms/step - loss: 0.0936 - mae: 0.1908 - val_loss: 0.1318 - val_mae: 0.2398
#
# Epoch 00037: val_mae improved from 0.24069 to 0.23975, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 38/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0857 - mae: 0.1851 - val_loss: 0.1293 - val_mae: 0.2346
#
# Epoch 00038: val_mae improved from 0.23975 to 0.23465, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 39/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.1002 - mae: 0.2018 - val_loss: 0.1268 - val_mae: 0.2313
#
# Epoch 00039: val_mae improved from 0.23465 to 0.23135, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 40/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.1056 - mae: 0.2096 - val_loss: 0.1243 - val_mae: 0.2274
#
# Epoch 00040: val_mae improved from 0.23135 to 0.22738, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 41/500
# 61/61 [==============================] - 1s 10ms/step - loss: 0.1013 - mae: 0.2030 - val_loss: 0.1218 - val_mae: 0.2255
#
# Epoch 00041: val_mae improved from 0.22738 to 0.22553, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 42/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0917 - mae: 0.1895 - val_loss: 0.1196 - val_mae: 0.2226
#
# Epoch 00042: val_mae improved from 0.22553 to 0.22263, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 43/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0913 - mae: 0.1886 - val_loss: 0.1173 - val_mae: 0.2201
#
# Epoch 00043: val_mae improved from 0.22263 to 0.22007, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 44/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.1022 - mae: 0.2028 - val_loss: 0.1151 - val_mae: 0.2170
#
# Epoch 00044: val_mae improved from 0.22007 to 0.21704, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 45/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0795 - mae: 0.1730 - val_loss: 0.1129 - val_mae: 0.2160
#
# Epoch 00045: val_mae improved from 0.21704 to 0.21596, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 46/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.1034 - mae: 0.2062 - val_loss: 0.1107 - val_mae: 0.2124
#
# Epoch 00046: val_mae improved from 0.21596 to 0.21238, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 47/500
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0802 - mae: 0.1765 - val_loss: 0.1087 - val_mae: 0.2105
#
# Epoch 00047: val_mae improved from 0.21238 to 0.21050, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 48/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0874 - mae: 0.1868 - val_loss: 0.1066 - val_mae: 0.2079
#
# Epoch 00048: val_mae improved from 0.21050 to 0.20791, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 49/500
# 61/61 [==============================] - 1s 10ms/step - loss: 0.0855 - mae: 0.1822 - val_loss: 0.1046 - val_mae: 0.2050
#
# Epoch 00049: val_mae improved from 0.20791 to 0.20501, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 50/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0825 - mae: 0.1764 - val_loss: 0.1028 - val_mae: 0.2027
#
# Epoch 00050: val_mae improved from 0.20501 to 0.20266, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 51/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0705 - mae: 0.1630 - val_loss: 0.1010 - val_mae: 0.2009
#
# Epoch 00051: val_mae improved from 0.20266 to 0.20089, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 52/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0844 - mae: 0.1844 - val_loss: 0.0990 - val_mae: 0.1994
#
# Epoch 00052: val_mae improved from 0.20089 to 0.19941, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 53/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0802 - mae: 0.1759 - val_loss: 0.0973 - val_mae: 0.1962
#
# Epoch 00053: val_mae improved from 0.19941 to 0.19623, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 54/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0675 - mae: 0.1573 - val_loss: 0.0955 - val_mae: 0.1947
#
# Epoch 00054: val_mae improved from 0.19623 to 0.19466, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 55/500
# 61/61 [==============================] - 1s 12ms/step - loss: 0.0724 - mae: 0.1668 - val_loss: 0.0938 - val_mae: 0.1923
#
# Epoch 00055: val_mae improved from 0.19466 to 0.19229, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 56/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0740 - mae: 0.1699 - val_loss: 0.0920 - val_mae: 0.1911
#
# Epoch 00056: val_mae improved from 0.19229 to 0.19111, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 57/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0749 - mae: 0.1665 - val_loss: 0.0904 - val_mae: 0.1885
#
# Epoch 00057: val_mae improved from 0.19111 to 0.18852, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 58/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0741 - mae: 0.1680 - val_loss: 0.0887 - val_mae: 0.1866
#
# Epoch 00058: val_mae improved from 0.18852 to 0.18661, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 59/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0780 - mae: 0.1732 - val_loss: 0.0871 - val_mae: 0.1837
#
# Epoch 00059: val_mae improved from 0.18661 to 0.18373, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 60/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0715 - mae: 0.1658 - val_loss: 0.0854 - val_mae: 0.1824
#
# Epoch 00060: val_mae improved from 0.18373 to 0.18241, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 61/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0673 - mae: 0.1586 - val_loss: 0.0838 - val_mae: 0.1812
#
# Epoch 00061: val_mae improved from 0.18241 to 0.18116, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 62/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0723 - mae: 0.1675 - val_loss: 0.0823 - val_mae: 0.1782
#
# Epoch 00062: val_mae improved from 0.18116 to 0.17820, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 63/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0678 - mae: 0.1602 - val_loss: 0.0807 - val_mae: 0.1767
#
# Epoch 00063: val_mae improved from 0.17820 to 0.17669, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 64/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0568 - mae: 0.1446 - val_loss: 0.0792 - val_mae: 0.1749
#
# Epoch 00064: val_mae improved from 0.17669 to 0.17486, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 65/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0620 - mae: 0.1524 - val_loss: 0.0777 - val_mae: 0.1738
#
# Epoch 00065: val_mae improved from 0.17486 to 0.17375, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 66/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0554 - mae: 0.1405 - val_loss: 0.0763 - val_mae: 0.1715
#
# Epoch 00066: val_mae improved from 0.17375 to 0.17149, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 67/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0606 - mae: 0.1497 - val_loss: 0.0747 - val_mae: 0.1700
#
# Epoch 00067: val_mae improved from 0.17149 to 0.17001, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 68/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0612 - mae: 0.1505 - val_loss: 0.0732 - val_mae: 0.1673
#
# Epoch 00068: val_mae improved from 0.17001 to 0.16728, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 69/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0547 - mae: 0.1404 - val_loss: 0.0718 - val_mae: 0.1651
#
# Epoch 00069: val_mae improved from 0.16728 to 0.16515, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 70/500
# 61/61 [==============================] - 1s 10ms/step - loss: 0.0632 - mae: 0.1538 - val_loss: 0.0703 - val_mae: 0.1635
#
# Epoch 00070: val_mae improved from 0.16515 to 0.16345, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 71/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0617 - mae: 0.1490 - val_loss: 0.0689 - val_mae: 0.1607
#
# Epoch 00071: val_mae improved from 0.16345 to 0.16073, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 72/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0474 - mae: 0.1321 - val_loss: 0.0675 - val_mae: 0.1606
#
# Epoch 00072: val_mae improved from 0.16073 to 0.16056, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 73/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0534 - mae: 0.1376 - val_loss: 0.0661 - val_mae: 0.1582
#
# Epoch 00073: val_mae improved from 0.16056 to 0.15816, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 74/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0428 - mae: 0.1240 - val_loss: 0.0648 - val_mae: 0.1565
#
# Epoch 00074: val_mae improved from 0.15816 to 0.15653, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 75/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0416 - mae: 0.1254 - val_loss: 0.0634 - val_mae: 0.1554
#
# Epoch 00075: val_mae improved from 0.15653 to 0.15539, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 76/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0589 - mae: 0.1493 - val_loss: 0.0621 - val_mae: 0.1526
#
# Epoch 00076: val_mae improved from 0.15539 to 0.15255, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 77/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0483 - mae: 0.1330 - val_loss: 0.0607 - val_mae: 0.1509
#
# Epoch 00077: val_mae improved from 0.15255 to 0.15086, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 78/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0389 - mae: 0.1199 - val_loss: 0.0594 - val_mae: 0.1505
#
# Epoch 00078: val_mae improved from 0.15086 to 0.15051, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 79/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0445 - mae: 0.1269 - val_loss: 0.0582 - val_mae: 0.1472
#
# Epoch 00079: val_mae improved from 0.15051 to 0.14718, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 80/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0422 - mae: 0.1231 - val_loss: 0.0569 - val_mae: 0.1464
#
# Epoch 00080: val_mae improved from 0.14718 to 0.14640, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 81/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0427 - mae: 0.1218 - val_loss: 0.0558 - val_mae: 0.1432
#
# Epoch 00081: val_mae improved from 0.14640 to 0.14317, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 82/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0455 - mae: 0.1281 - val_loss: 0.0546 - val_mae: 0.1420
#
# Epoch 00082: val_mae improved from 0.14317 to 0.14204, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 83/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0429 - mae: 0.1241 - val_loss: 0.0535 - val_mae: 0.1398
#
# Epoch 00083: val_mae improved from 0.14204 to 0.13982, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 84/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0422 - mae: 0.1216 - val_loss: 0.0523 - val_mae: 0.1389
#
# Epoch 00084: val_mae improved from 0.13982 to 0.13888, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 85/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0366 - mae: 0.1160 - val_loss: 0.0512 - val_mae: 0.1372
#
# Epoch 00085: val_mae improved from 0.13888 to 0.13721, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 86/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0381 - mae: 0.1195 - val_loss: 0.0501 - val_mae: 0.1355
#
# Epoch 00086: val_mae improved from 0.13721 to 0.13547, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 87/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0382 - mae: 0.1153 - val_loss: 0.0491 - val_mae: 0.1342
#
# Epoch 00087: val_mae improved from 0.13547 to 0.13420, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 88/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0337 - mae: 0.1087 - val_loss: 0.0481 - val_mae: 0.1325
#
# Epoch 00088: val_mae improved from 0.13420 to 0.13252, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 89/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0368 - mae: 0.1150 - val_loss: 0.0470 - val_mae: 0.1314
#
# Epoch 00089: val_mae improved from 0.13252 to 0.13142, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 90/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0345 - mae: 0.1101 - val_loss: 0.0461 - val_mae: 0.1289
#
# Epoch 00090: val_mae improved from 0.13142 to 0.12886, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 91/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0333 - mae: 0.1072 - val_loss: 0.0451 - val_mae: 0.1278
#
# Epoch 00091: val_mae improved from 0.12886 to 0.12778, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 92/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0327 - mae: 0.1062 - val_loss: 0.0441 - val_mae: 0.1267
#
# Epoch 00092: val_mae improved from 0.12778 to 0.12671, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 93/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0303 - mae: 0.1044 - val_loss: 0.0432 - val_mae: 0.1259
#
# Epoch 00093: val_mae improved from 0.12671 to 0.12588, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 94/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0300 - mae: 0.1042 - val_loss: 0.0423 - val_mae: 0.1240
#
# Epoch 00094: val_mae improved from 0.12588 to 0.12401, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 95/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0350 - mae: 0.1134 - val_loss: 0.0414 - val_mae: 0.1228
#
# Epoch 00095: val_mae improved from 0.12401 to 0.12276, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 96/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0272 - mae: 0.0984 - val_loss: 0.0406 - val_mae: 0.1215
#
# Epoch 00096: val_mae improved from 0.12276 to 0.12155, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 97/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0315 - mae: 0.1056 - val_loss: 0.0398 - val_mae: 0.1201
#
# Epoch 00097: val_mae improved from 0.12155 to 0.12011, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 98/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0275 - mae: 0.0994 - val_loss: 0.0389 - val_mae: 0.1194
#
# Epoch 00098: val_mae improved from 0.12011 to 0.11938, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 99/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0332 - mae: 0.1100 - val_loss: 0.0381 - val_mae: 0.1172
#
# Epoch 00099: val_mae improved from 0.11938 to 0.11719, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 100/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0259 - mae: 0.0966 - val_loss: 0.0374 - val_mae: 0.1161
#
# Epoch 00100: val_mae improved from 0.11719 to 0.11614, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 101/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0277 - mae: 0.0997 - val_loss: 0.0366 - val_mae: 0.1158
#
# Epoch 00101: val_mae improved from 0.11614 to 0.11582, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 102/500
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0288 - mae: 0.1023 - val_loss: 0.0359 - val_mae: 0.1137
#
# Epoch 00102: val_mae improved from 0.11582 to 0.11374, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 103/500
# 61/61 [==============================] - 1s 12ms/step - loss: 0.0252 - mae: 0.0947 - val_loss: 0.0352 - val_mae: 0.1131
#
# Epoch 00103: val_mae improved from 0.11374 to 0.11314, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 104/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0240 - mae: 0.0927 - val_loss: 0.0345 - val_mae: 0.1126
#
# Epoch 00104: val_mae improved from 0.11314 to 0.11259, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 105/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0265 - mae: 0.0985 - val_loss: 0.0339 - val_mae: 0.1109
#
# Epoch 00105: val_mae improved from 0.11259 to 0.11088, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 106/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0236 - mae: 0.0908 - val_loss: 0.0332 - val_mae: 0.1100
#
# Epoch 00106: val_mae improved from 0.11088 to 0.11001, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 107/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0275 - mae: 0.0978 - val_loss: 0.0325 - val_mae: 0.1087
#
# Epoch 00107: val_mae improved from 0.11001 to 0.10866, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 108/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0239 - mae: 0.0923 - val_loss: 0.0319 - val_mae: 0.1074
#
# Epoch 00108: val_mae improved from 0.10866 to 0.10736, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 109/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0244 - mae: 0.0922 - val_loss: 0.0313 - val_mae: 0.1067
#
# Epoch 00109: val_mae improved from 0.10736 to 0.10666, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 110/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0238 - mae: 0.0921 - val_loss: 0.0307 - val_mae: 0.1059
#
# Epoch 00110: val_mae improved from 0.10666 to 0.10592, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 111/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0220 - mae: 0.0881 - val_loss: 0.0302 - val_mae: 0.1047
#
# Epoch 00111: val_mae improved from 0.10592 to 0.10468, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 112/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0237 - mae: 0.0931 - val_loss: 0.0296 - val_mae: 0.1044
#
# Epoch 00112: val_mae improved from 0.10468 to 0.10440, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 113/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0240 - mae: 0.0939 - val_loss: 0.0291 - val_mae: 0.1033
#
# Epoch 00113: val_mae improved from 0.10440 to 0.10334, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 114/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0235 - mae: 0.0926 - val_loss: 0.0286 - val_mae: 0.1020
#
# Epoch 00114: val_mae improved from 0.10334 to 0.10200, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 115/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0200 - mae: 0.0843 - val_loss: 0.0281 - val_mae: 0.1015
#
# Epoch 00115: val_mae improved from 0.10200 to 0.10149, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 116/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0251 - mae: 0.0963 - val_loss: 0.0275 - val_mae: 0.1006
#
# Epoch 00116: val_mae improved from 0.10149 to 0.10061, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 117/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0196 - mae: 0.0834 - val_loss: 0.0271 - val_mae: 0.1001
#
# Epoch 00117: val_mae improved from 0.10061 to 0.10011, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 118/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0189 - mae: 0.0830 - val_loss: 0.0266 - val_mae: 0.0995
#
# Epoch 00118: val_mae improved from 0.10011 to 0.09951, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 119/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0235 - mae: 0.0906 - val_loss: 0.0262 - val_mae: 0.0979
#
# Epoch 00119: val_mae improved from 0.09951 to 0.09792, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 120/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0228 - mae: 0.0895 - val_loss: 0.0257 - val_mae: 0.0972
#
# Epoch 00120: val_mae improved from 0.09792 to 0.09720, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 121/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0209 - mae: 0.0866 - val_loss: 0.0253 - val_mae: 0.0970
#
# Epoch 00121: val_mae improved from 0.09720 to 0.09701, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 122/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0200 - mae: 0.0869 - val_loss: 0.0249 - val_mae: 0.0965
#
# Epoch 00122: val_mae improved from 0.09701 to 0.09649, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 123/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0229 - mae: 0.0919 - val_loss: 0.0244 - val_mae: 0.0955
#
# Epoch 00123: val_mae improved from 0.09649 to 0.09545, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 124/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0218 - mae: 0.0878 - val_loss: 0.0241 - val_mae: 0.0949
#
# Epoch 00124: val_mae improved from 0.09545 to 0.09487, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 125/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0226 - mae: 0.0912 - val_loss: 0.0236 - val_mae: 0.0945
#
# Epoch 00125: val_mae improved from 0.09487 to 0.09454, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 126/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0188 - mae: 0.0843 - val_loss: 0.0232 - val_mae: 0.0943
#
# Epoch 00126: val_mae improved from 0.09454 to 0.09426, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 127/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0164 - mae: 0.0787 - val_loss: 0.0229 - val_mae: 0.0935
#
# Epoch 00127: val_mae improved from 0.09426 to 0.09354, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 128/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0196 - mae: 0.0842 - val_loss: 0.0225 - val_mae: 0.0928
#
# Epoch 00128: val_mae improved from 0.09354 to 0.09284, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 129/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0175 - mae: 0.0801 - val_loss: 0.0222 - val_mae: 0.0924
#
# Epoch 00129: val_mae improved from 0.09284 to 0.09238, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 130/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0213 - mae: 0.0881 - val_loss: 0.0218 - val_mae: 0.0917
#
# Epoch 00130: val_mae improved from 0.09238 to 0.09166, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 131/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0186 - mae: 0.0824 - val_loss: 0.0215 - val_mae: 0.0912
#
# Epoch 00131: val_mae improved from 0.09166 to 0.09124, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 132/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0167 - mae: 0.0778 - val_loss: 0.0212 - val_mae: 0.0908
#
# Epoch 00132: val_mae improved from 0.09124 to 0.09085, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 133/500
# 61/61 [==============================] - 1s 12ms/step - loss: 0.0192 - mae: 0.0843 - val_loss: 0.0208 - val_mae: 0.0901
#
# Epoch 00133: val_mae improved from 0.09085 to 0.09011, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 134/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0176 - mae: 0.0821 - val_loss: 0.0205 - val_mae: 0.0896
#
# Epoch 00134: val_mae improved from 0.09011 to 0.08958, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 135/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0214 - mae: 0.0892 - val_loss: 0.0202 - val_mae: 0.0888
#
# Epoch 00135: val_mae improved from 0.08958 to 0.08878, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 136/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0174 - mae: 0.0819 - val_loss: 0.0199 - val_mae: 0.0886
#
# Epoch 00136: val_mae improved from 0.08878 to 0.08858, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 137/500
# 61/61 [==============================] - 1s 12ms/step - loss: 0.0154 - mae: 0.0761 - val_loss: 0.0196 - val_mae: 0.0882
#
# Epoch 00137: val_mae improved from 0.08858 to 0.08816, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 138/500
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0171 - mae: 0.0807 - val_loss: 0.0193 - val_mae: 0.0879
#
# Epoch 00138: val_mae improved from 0.08816 to 0.08794, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 139/500
# 61/61 [==============================] - 1s 12ms/step - loss: 0.0159 - mae: 0.0791 - val_loss: 0.0191 - val_mae: 0.0877
#
# Epoch 00139: val_mae improved from 0.08794 to 0.08772, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 140/500
# 61/61 [==============================] - 1s 12ms/step - loss: 0.0170 - mae: 0.0805 - val_loss: 0.0188 - val_mae: 0.0869
#
# Epoch 00140: val_mae improved from 0.08772 to 0.08688, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 141/500
# 61/61 [==============================] - 1s 12ms/step - loss: 0.0176 - mae: 0.0810 - val_loss: 0.0185 - val_mae: 0.0866
#
# Epoch 00141: val_mae improved from 0.08688 to 0.08662, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 142/500
# 61/61 [==============================] - 1s 12ms/step - loss: 0.0147 - mae: 0.0757 - val_loss: 0.0183 - val_mae: 0.0864
#
# Epoch 00142: val_mae improved from 0.08662 to 0.08636, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 143/500
# 61/61 [==============================] - 1s 12ms/step - loss: 0.0151 - mae: 0.0768 - val_loss: 0.0180 - val_mae: 0.0859
#
# Epoch 00143: val_mae improved from 0.08636 to 0.08585, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 144/500
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0146 - mae: 0.0758 - val_loss: 0.0178 - val_mae: 0.0853
#
# Epoch 00144: val_mae improved from 0.08585 to 0.08533, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 145/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.0141 - mae: 0.0743 - val_loss: 0.0176 - val_mae: 0.0849
#
# Epoch 00145: val_mae improved from 0.08533 to 0.08486, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 146/500
# 61/61 [==============================] - 1s 12ms/step - loss: 0.0153 - mae: 0.0766 - val_loss: 0.0173 - val_mae: 0.0844
#
# Epoch 00146: val_mae improved from 0.08486 to 0.08437, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 147/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0115 - mae: 0.0685 - val_loss: 0.0171 - val_mae: 0.0843
#
# Epoch 00147: val_mae improved from 0.08437 to 0.08427, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 148/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0135 - mae: 0.0741 - val_loss: 0.0169 - val_mae: 0.0839
#
# Epoch 00148: val_mae improved from 0.08427 to 0.08391, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 149/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0155 - mae: 0.0788 - val_loss: 0.0167 - val_mae: 0.0832
#
# Epoch 00149: val_mae improved from 0.08391 to 0.08324, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 150/500
# 61/61 [==============================] - 1s 12ms/step - loss: 0.0150 - mae: 0.0769 - val_loss: 0.0164 - val_mae: 0.0832
#
# Epoch 00150: val_mae improved from 0.08324 to 0.08318, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 151/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0144 - mae: 0.0745 - val_loss: 0.0163 - val_mae: 0.0823
#
# Epoch 00151: val_mae improved from 0.08318 to 0.08227, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 152/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0126 - mae: 0.0728 - val_loss: 0.0161 - val_mae: 0.0824
#
# Epoch 00152: val_mae did not improve from 0.08227
# Epoch 153/500
# 61/61 [==============================] - 1s 11ms/step - loss: 0.0140 - mae: 0.0755 - val_loss: 0.0159 - val_mae: 0.0819
#
# ...
# Epoch 447/500
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0042 - mae: 0.0452 - val_loss: 0.0045 - val_mae: 0.0495
#
# Epoch 00447: val_mae improved from 0.04950 to 0.04945, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 448/500
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0042 - mae: 0.0464 - val_loss: 0.0045 - val_mae: 0.0494
#
# Epoch 00448: val_mae improved from 0.04945 to 0.04937, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 449/500
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0046 - mae: 0.0478 - val_loss: 0.0045 - val_mae: 0.0494
#
# Epoch 00449: val_mae did not improve from 0.04937
# Epoch 450/500
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0047 - mae: 0.0481 - val_loss: 0.0045 - val_mae: 0.0493
#
# Epoch 00450: val_mae improved from 0.04937 to 0.04930, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 451/500
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0037 - mae: 0.0440 - val_loss: 0.0045 - val_mae: 0.0493
#
# Epoch 00451: val_mae improved from 0.04930 to 0.04926, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 452/500
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0048 - mae: 0.0485 - val_loss: 0.0045 - val_mae: 0.0492
#
# Epoch 00452: val_mae improved from 0.04926 to 0.04923, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 453/500
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0044 - mae: 0.0464 - val_loss: 0.0045 - val_mae: 0.0492
#
# Epoch 00453: val_mae improved from 0.04923 to 0.04922, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 454/500
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0041 - mae: 0.0458 - val_loss: 0.0044 - val_mae: 0.0491
#
# Epoch 00454: val_mae improved from 0.04922 to 0.04914, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 455/500
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0044 - mae: 0.0461 - val_loss: 0.0044 - val_mae: 0.0491
#
# Epoch 00455: val_mae improved from 0.04914 to 0.04911, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 456/500
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0042 - mae: 0.0456 - val_loss: 0.0044 - val_mae: 0.0490
#
# Epoch 00456: val_mae improved from 0.04911 to 0.04905, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 457/500
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0041 - mae: 0.0450 - val_loss: 0.0044 - val_mae: 0.0491
#
# Epoch 00457: val_mae did not improve from 0.04905
# Epoch 458/500
# 61/61 [==============================] - 1s 12ms/step - loss: 0.0043 - mae: 0.0460 - val_loss: 0.0044 - val_mae: 0.0490
#
# Epoch 00458: val_mae improved from 0.04905 to 0.04905, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 459/500
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0045 - mae: 0.0473 - val_loss: 0.0044 - val_mae: 0.0489
#
# Epoch 00459: val_mae improved from 0.04905 to 0.04891, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 460/500
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0044 - mae: 0.0465 - val_loss: 0.0044 - val_mae: 0.0489
#
# Epoch 00460: val_mae did not improve from 0.04891
# Epoch 461/500
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0047 - mae: 0.0473 - val_loss: 0.0044 - val_mae: 0.0488
#
# Epoch 00461: val_mae improved from 0.04891 to 0.04884, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 462/500
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0039 - mae: 0.0443 - val_loss: 0.0044 - val_mae: 0.0489
#
# Epoch 00462: val_mae did not improve from 0.04884
# Epoch 463/500
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0040 - mae: 0.0454 - val_loss: 0.0044 - val_mae: 0.0488
#
# Epoch 00463: val_mae improved from 0.04884 to 0.04881, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 464/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.0044 - mae: 0.0463 - val_loss: 0.0044 - val_mae: 0.0487
#
# Epoch 00464: val_mae improved from 0.04881 to 0.04874, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 465/500
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0046 - mae: 0.0472 - val_loss: 0.0044 - val_mae: 0.0487
#
# Epoch 00465: val_mae improved from 0.04874 to 0.04872, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 466/500
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0038 - mae: 0.0437 - val_loss: 0.0044 - val_mae: 0.0487
#
# Epoch 00466: val_mae improved from 0.04872 to 0.04871, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 467/500
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0045 - mae: 0.0474 - val_loss: 0.0043 - val_mae: 0.0486
#
# Epoch 00467: val_mae improved from 0.04871 to 0.04861, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 468/500
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0039 - mae: 0.0446 - val_loss: 0.0043 - val_mae: 0.0486
#
# Epoch 00468: val_mae did not improve from 0.04861
# Epoch 469/500
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0044 - mae: 0.0467 - val_loss: 0.0043 - val_mae: 0.0485
#
# Epoch 00469: val_mae improved from 0.04861 to 0.04852, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 470/500
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0043 - mae: 0.0455 - val_loss: 0.0043 - val_mae: 0.0485
#
# Epoch 00470: val_mae improved from 0.04852 to 0.04850, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 471/500
# 61/61 [==============================] - 1s 16ms/step - loss: 0.0050 - mae: 0.0484 - val_loss: 0.0043 - val_mae: 0.0485
#
# Epoch 00471: val_mae did not improve from 0.04850
# Epoch 472/500
# 61/61 [==============================] - 1s 14ms/step - loss: 0.0040 - mae: 0.0452 - val_loss: 0.0043 - val_mae: 0.0484
#
# Epoch 00472: val_mae improved from 0.04850 to 0.04845, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 473/500
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0044 - mae: 0.0463 - val_loss: 0.0043 - val_mae: 0.0484
#
# Epoch 00473: val_mae improved from 0.04845 to 0.04844, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 474/500
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0039 - mae: 0.0438 - val_loss: 0.0043 - val_mae: 0.0484
#
# Epoch 00474: val_mae improved from 0.04844 to 0.04841, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 475/500
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0036 - mae: 0.0429 - val_loss: 0.0043 - val_mae: 0.0483
#
# Epoch 00475: val_mae improved from 0.04841 to 0.04835, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 476/500
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0045 - mae: 0.0460 - val_loss: 0.0043 - val_mae: 0.0483
#
# Epoch 00476: val_mae improved from 0.04835 to 0.04834, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 477/500
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0041 - mae: 0.0446 - val_loss: 0.0043 - val_mae: 0.0483
#
# Epoch 00477: val_mae improved from 0.04834 to 0.04826, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 478/500
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0041 - mae: 0.0444 - val_loss: 0.0043 - val_mae: 0.0483
#
# Epoch 00478: val_mae did not improve from 0.04826
# Epoch 479/500
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0038 - mae: 0.0435 - val_loss: 0.0043 - val_mae: 0.0482
#
# Epoch 00479: val_mae improved from 0.04826 to 0.04819, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 480/500
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0041 - mae: 0.0449 - val_loss: 0.0042 - val_mae: 0.0481
#
# Epoch 00480: val_mae improved from 0.04819 to 0.04813, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 481/500
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0043 - mae: 0.0455 - val_loss: 0.0042 - val_mae: 0.0481
#
# Epoch 00481: val_mae did not improve from 0.04813
# Epoch 482/500
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0042 - mae: 0.0460 - val_loss: 0.0042 - val_mae: 0.0481
#
# Epoch 00482: val_mae improved from 0.04813 to 0.04812, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 483/500
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0037 - mae: 0.0433 - val_loss: 0.0042 - val_mae: 0.0481
#
# Epoch 00483: val_mae improved from 0.04812 to 0.04806, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 484/500
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0039 - mae: 0.0442 - val_loss: 0.0042 - val_mae: 0.0481
#
# Epoch 00484: val_mae did not improve from 0.04806
# Epoch 485/500
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0042 - mae: 0.0456 - val_loss: 0.0042 - val_mae: 0.0479
#
# Epoch 00485: val_mae improved from 0.04806 to 0.04795, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 486/500
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0042 - mae: 0.0462 - val_loss: 0.0042 - val_mae: 0.0479
#
# Epoch 00486: val_mae improved from 0.04795 to 0.04792, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 487/500
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0045 - mae: 0.0469 - val_loss: 0.0042 - val_mae: 0.0479
#
# Epoch 00487: val_mae improved from 0.04792 to 0.04789, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 488/500
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0040 - mae: 0.0442 - val_loss: 0.0042 - val_mae: 0.0479
#
# Epoch 00488: val_mae improved from 0.04789 to 0.04787, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 489/500
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0044 - mae: 0.0469 - val_loss: 0.0042 - val_mae: 0.0478
#
# Epoch 00489: val_mae improved from 0.04787 to 0.04784, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 490/500
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0042 - mae: 0.0458 - val_loss: 0.0042 - val_mae: 0.0478
#
# Epoch 00490: val_mae improved from 0.04784 to 0.04779, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 491/500
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0041 - mae: 0.0448 - val_loss: 0.0042 - val_mae: 0.0478
#
# Epoch 00491: val_mae did not improve from 0.04779
# Epoch 492/500
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0046 - mae: 0.0470 - val_loss: 0.0042 - val_mae: 0.0478
#
# Epoch 00492: val_mae improved from 0.04779 to 0.04775, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 493/500
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0043 - mae: 0.0464 - val_loss: 0.0042 - val_mae: 0.0477
#
# Epoch 00493: val_mae improved from 0.04775 to 0.04771, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 494/500
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0033 - mae: 0.0414 - val_loss: 0.0042 - val_mae: 0.0477
#
# Epoch 00494: val_mae improved from 0.04771 to 0.04765, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 495/500
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0041 - mae: 0.0450 - val_loss: 0.0041 - val_mae: 0.0477
#
# Epoch 00495: val_mae did not improve from 0.04765
# Epoch 496/500
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0045 - mae: 0.0470 - val_loss: 0.0041 - val_mae: 0.0476
#
# Epoch 00496: val_mae improved from 0.04765 to 0.04762, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 497/500
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0041 - mae: 0.0456 - val_loss: 0.0041 - val_mae: 0.0475
#
# Epoch 00497: val_mae improved from 0.04762 to 0.04754, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 498/500
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0043 - mae: 0.0462 - val_loss: 0.0041 - val_mae: 0.0475
#
# Epoch 00498: val_mae improved from 0.04754 to 0.04751, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 499/500
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0039 - mae: 0.0445 - val_loss: 0.0041 - val_mae: 0.0475
#
# Epoch 00499: val_mae improved from 0.04751 to 0.04748, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Epoch 500/500
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0043 - mae: 0.0456 - val_loss: 0.0041 - val_mae: 0.0475
#
# Epoch 00500: val_mae improved from 0.04748 to 0.04747, saving model to /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# ==============================
# Training Finished, took 7m 25s
# Best model: /content/drive/MyDrive/Playground/BitcoinPrice/model/best_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5
# Last model: /content/drive/MyDrive/Playground/BitcoinPrice/model/last_model-LSTM-afad8770-e22b-11eb-92de-0242ac1c0002.h5

# %%
# Plot training and loss accuracy
plot_training(history, train_id)
# Out:
# ### Training Loss and MAE

# %%
# Load best model and evaluate
model = load_model(best_model)
model_evaluation(train_id, model, X_train, X_test, y_train, y_test)
# Out:
# ### Training Accuracy
# 61/61 [==============================] - 1s 5ms/step - loss: 0.0041 - mae: 0.0448
# loss: 0.41
# mae: 4.48
# ### Validation Accuracy
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0041 - mae: 0.0475
# loss: 0.41
# mae: 4.75
