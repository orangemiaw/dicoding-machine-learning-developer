# %% [markdown]
# # Rock Paper Scissors Modeling and Prediction
#
# ---
#
# <p align="center">
#   <img src="https://api.timeforkids.com/wp-content/uploads/2020/11/rockpaperscissors.jpg" width="350">
# </p>
#
# Disini saya mengembangkan 2 model arsitektur yaitu **CCN from Scratch** dan **VGG16 + CNN dengan Transfer Learning**. Dari hasil training didapatkan akurasi sebagai berikut:
#
# <center>
#   <b>Tabel 1. Perbandingan Antar Model</b>
# </center>
#
# | Model | Tran Acc. (%) | Validation Acc. (%) | Time |
# |-------|---------------|---------------------|------|
# |CNN | 97.11  | 97.14  | 5m 50s |
# |VGG16 + CNN | 97.79  | 97.94  | 6m 40s |
#
# Dari hasil tersebut menunjukan bahwa model yang dibangun dengan **VGG16 + CNN** memiliki tingkat akurasi yang lebih baik namun membutuhkan waktu training yang lebih lama dibandingkan dengan menggunakan model arsitektur **CCN from Scratch**.

# %%
# !pip install split_folders
# !pip install awesome-slugify
# Out:
# Requirement already satisfied: split_folders in /usr/local/lib/python3.7/dist-packages (0.4.3)
# Requirement already satisfied: awesome-slugify in /usr/local/lib/python3.7/dist-packages (1.6.5)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from awesome-slugify) (2019.12.20)
# Requirement already satisfied: Unidecode<0.05,>=0.04.14 in /usr/local/lib/python3.7/dist-packages (from awesome-slugify) (0.4.21)

# %%
# import library needed
import tensorflow as tf
from tensorflow import keras
from keras.utils.vis_utils import plot_model
from keras.optimizers import Adam
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
from keras.models import load_model
from keras.models import Sequential
from keras.callbacks import ModelCheckpoint
from keras.callbacks import EarlyStopping
from keras.callbacks import CSVLogger
from keras import layers
from keras import Model
from keras.applications.vgg16 import VGG16

from google.colab import files
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
import seaborn as sn
import cv2
import numpy as np
import pandas as pd

import os
import time
import uuid
import glob
import warnings
import splitfolders
from tqdm import tqdm
from IPython.display import Markdown
from IPython.display import display
from slugify import slugify

# Ignore the unwanted warning messages
warnings.filterwarnings('ignore')

# Define base path for worksheet
BASE_PATH = '/content/drive/MyDrive/Playground'
# Size of input images
IMAGE_HEIGHT=224
IMAGE_WIDTH=224
# No. of class
NUM_CLASS=3
# No. of images to be yielded from the generator per batch
BATCH_SIZE=32
# Learning rate
LEARNING_RATE=0.001
# Number of iterations
EPOCH=20

# %%
# Mount our google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Helper

# %%
# Print in markdown format
def printmd(string):
    display(Markdown(string))

# Check total of data
def count_data(path):
  count_path = 0
  for dir in os.listdir(path):
    count_sub = 0
    sub = glob.glob(os.path.join(path, dir) + '/*.png')
    for file in sub:
      count_sub += 1
      count_path += 1

    print("{} : {}".format(dir, count_sub))

  print("\nTotal data : {}".format(count_path))

# Plot image
def plot_image(images):
  fig, axes = plt.subplots(1, 5, figsize=(20,20))
  axes = axes.flatten()
  for image, pl in zip(images, axes):
    pl.imshow(image)
    pl.axis('off')

# Plot training loss and accuracy
def plot_training(history, title, save=True, save_path=os.path.join(BASE_PATH, 'visualization')):
    printmd("### Training Loss and Accuracy")
    
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epoch_list = range(1, len(acc) + 1)
    
    plt.figure(figsize=(8, 6))
    plt.plot(loss, label='Training Loss')
    plt.plot(val_loss, label='Validation Loss')
    plt.legend(loc=0, fontsize='large')
    plt.xlabel("Epoch #", fontsize=14)
    plt.ylabel("Loss", fontsize=14)
    plt.show()
    
    if save is True:
        filename = slugify(title) + '_loss_model.png'
        plt.savefig(save_path + '/' + filename)

    plt.figure(figsize=(8, 6))
    plt.plot(acc, label='Training Accuracy')
    plt.plot(val_acc, label='Validation Accuracy')
    plt.legend(loc=4, fontsize='large')
    plt.xlabel("Epoch #", fontsize=14)
    plt.ylabel("Accuracy", fontsize=14)
    plt.show()
    
    if save is True:
        filename = slugify(title) + '_acc_model.png'
        plt.savefig(save_path + '/' + filename)

# Plot confusion matrix
def plot_confusion_matrix(classes, preds, title, save=True, save_path=os.path.join(BASE_PATH, 'visualization')):
    printmd('#### Confusion Matrix')
    cm = confusion_matrix(classes, preds)
    print('True Positive (TP):', cm[0][0])
    print('False Positive (FP):', cm[0][1])
    print('False Negative (FN):', cm[1][0])
    print('True Negative (TN):', cm[1][1])
    df_cm = pd.DataFrame(cm, range(3), range(3))
    sn.set(font_scale=1.4) # for label size
    sn.heatmap(df_cm, annot=True, fmt=".0f", annot_kws={"size": 16}) # font size
    plt.ylabel('Actual label', size = 20)
    plt.xlabel('Predicted label', size = 20)
    plt.xticks(np.arange(3), ['paper', 'rock', 'scissors'], size = 16)
    plt.yticks(np.arange(3), ['paper', 'rock', 'scissors'], size = 16)
    plt.ylim([3, 0])
    
    if save is True:
        filename = slugify(title) + '_confusion_matrix.png'
        plt.savefig(save_path + '/' + filename)

    plt.show()
    
    # Calculate accuracy
    calculated_acc = (cm[0][0]+cm[1][1])/(cm[0][0]+cm[0][1]+cm[1][0]+ cm[1][1])
    print("Calculated Accuracy:", calculated_acc*100)

# Table classification report
def table_classification_report(classes, preds):
    printmd('#### Classification Report')
    target_names = ['paper', 'rock', 'scissors']
    print(classification_report(classes, preds, target_names=target_names))

    print('Accuracy: {:.2f}\n'.format(accuracy_score(classes, preds)))

    print('Macro Precision: {:.2f}'.format(precision_score(classes, preds, average='macro')))
    print('Macro Recall: {:.2f}'.format(recall_score(classes, preds, average='macro')))
    print('Macro F1-score: {:.2f}\n'.format(f1_score(classes, preds, average='macro')))

    print('Weighted Precision: {:.2f}'.format(precision_score(classes, preds, average='weighted')))
    print('Weighted Recall: {:.2f}'.format(recall_score(classes, preds, average='weighted')))
    print('Weighted F1-score: {:.2f}\n'.format(f1_score(classes, preds, average='weighted')))

# Evaluate model, confusion matrix and classification report
def model_evaluation(title, model, train_generator, validation_generator, save=True, save_path=os.path.join(BASE_PATH, 'visualization')):
    printmd('### Training Accuracy')
    loss, val_acc = model.evaluate_generator(train_generator, verbose=1)

    print("loss: %.2f" % (loss*100))
    print("acc: %.2f" % (val_acc*100))
    
    printmd('### Validation Accuracy')
    loss, val_acc = model.evaluate_generator(validation_generator, verbose=1)

    print("loss: %.2f" % (loss*100))
    print("acc: %.2f" % (val_acc*100))
    
    printmd('### Evaluation of Model Performance')
    Y_pred = model.predict_generator(validation_generator, verbose=1)
    y_pred = np.argmax(Y_pred, axis=1)
    x_pred = validation_generator.classes
    
    # Plot confusion matrix
    plot_confusion_matrix(x_pred, y_pred, title, save, save_path)
    
    # Table classification report
    table_classification_report(x_pred, y_pred)

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ###
png
#   inflating: /content/drive/MyDrive/Playground/__MACOSX/rockpaperscissors/rps-cv-images/scissors/._1vQCX4af6hQmuwxZ.png
#   inflating: /content/drive/MyDrive/Playground/rockpaperscissors/rps-cv-images/scissors/o6sFIzkVY4xKTgrH.png
#   inflating: /content/drive/MyDrive/Playground/__MACOSX/rockpaperscissors/rps-cv-images/scissors/._o6sFIzkVY4xKTgrH.png
#   inflating: /content/drive/MyDrive/Playground/rockpaperscissors/rps-cv-images/scissors/P2mN2BN7A8eaYm1l.png
#   inflating: /content/drive/MyDrive/Playground/__MACOSX/rockpaperscissors/rps-cv-images/scissors/._P2mN2BN7A8eaYm1l.png
#   inflating: /content/drive/MyDrive/Playground/rockpaperscissors/rps-cv-images/scissors/F0440RDr6eKJusnY.png
#   inflating: /content/drive/MyDrive/Playground/__MACOSX/rockpaperscissors/rps-cv-images/scissors/._F0440RDr6eKJusnY.png
#   inflating: /content/drive/MyDrive/Playground/rockpaperscissors/rps-cv-images/scissors/DH7iguASbWIzzBnT.png
#   inflating: /content/drive/MyDrive/Playground/__MACOSX/rockpaperscissors/rps-cv-images/scissors/._DH7iguASbWIzzBnT.png
#   inflating: /content/drive/MyDrive/Playground/rockpaperscissors/rps-cv-images/scissors/ik80sIT0Ao6APY3M.png
#   inflating: /content/drive/MyDrive/Playground/__MACOSX/rockpaperscissors/rps-cv-images/scissors/._ik80sIT0Ao6APY3M.png
#   inflating: /content/drive/MyDrive/Playground/rockpaperscissors/rps-cv-images/scissors/aRca3k5D1oCHVx0h.png
#   inflating: /content/drive/MyDrive/Playground/__MACOSX/rockpaperscissors/rps-cv-images/scissors/._aRca3k5D1oCHVx0h.png
#   inflating: /content/drive/MyDrive/Playground/rockpaperscissors/rps-cv-images/scissors/0657zSfiTYzP2jrl.png
#   inflating: /content/drive/MyDrive/Playground/__MACOSX/rockpaperscissors/rps-cv-images/scissors/._0657zSfiTYzP2jrl.png
#   inflating: /content/drive/MyDrive/Playground/rockpaperscissors/rps-cv-images/scissors/S2VG3n7WLkBpjNb1.png
#   inflating: /content/drive/MyDrive/Playground/__MACOSX/rockpaperscissors/rps-cv-images/scissors/._S2VG3n7WLkBpjNb1.png
#   inflating: /content/drive/MyDrive/Playground/rockpaperscissors/rps-cv-images/scissors/Bd18RfxcJr6O5n6j.png
#   inflating: /content/drive/MyDrive/Playground/__MACOSX/rockpaperscissors/rps-cv-images/scissors/._Bd18RfxcJr6O5n6j.png
#   inflating: /content/drive/MyDrive/Playground/rockpaperscissors/rps-cv-images/scissors/wT8z7icdMJt816Ix.png
#   inflating: /content/drive/MyDrive/Playground/__MACOSX/rockpaperscissors/rps-cv-images/scissors/._wT8z7icdMJt816Ix.png
#   inflating: /content/drive/MyDrive/Playground/rockpaperscissors/rps-cv-images/scissors/BJwCAwQV0EWaUT1X.png
#   inflating: /content/drive/MyDrive/Playground/__MACOSX/rockpaperscissors/rps-cv-images/scissors/._BJwCAwQV0EWaUT1X.png
#   inflating: /content/drive/MyDrive/Playground/rockpaperscissors/rps-cv-images/scissors/Qonst5LFs961D77L.png
#   inflating: /content/drive/MyDrive/Playground/__MACOSX/rockpaperscissors/rps-cv-images/scissors/._Qonst5LFs961D77L.png
#   inflating: /content/drive/MyDrive/Playground/rockpaperscissors/rps-cv-images/scissors/WoS4fluqoRRsfjle.png
#   inflating: /content/drive/MyDrive/Playground/__MACOSX/rockpaperscissors/rps-cv-images/scissors/._WoS4fluqoRRsfjle.png
#   inflating: /content/drive/MyDrive/Playground/rockpaperscissors/rps-cv-images/scissors/R9xpzPuawT5aH69c.png
#   inflating: /content/drive/MyDrive/Playground/__MACOSX/rockpaperscissors/rps-cv-images/scissors/._R9xpzPuawT5aH69c.png
#   inflating: /content/drive/MyDrive/Playground/rockpaperscissors/rps-cv-images/scissors/JWz75J1U5sGr1FH2.png
#   inflating: /content/drive/MyDrive/Playground/__MACOSX/rockpaperscissors/rps-cv-images/scissors/._JWz75J1U5sGr1FH2.png
#   inflating: /content/drive/MyDrive/Playground/rockpaperscissors/rps-cv-images/scissors/gbGB4caRQYsV8ZcR.png
#   inflating: /content/drive/MyDrive/Playground/__MACOSX/rockpaperscissors/rps-cv-images/scissors/._gbGB4caRQYsV8ZcR.png
#   inflating: /content/drive/MyDrive/Playground/rockpaperscissors/rps-cv-images/scissors/mdSPppG9v9OmnIyY.png
#   inflating: /content/drive/MyDrive/Playground/__MACOSX/rockpaperscissors/rps-cv-images/scissors/._mdSPppG9v9OmnIyY.png
#   inflating: /content/drive/MyDrive/Playground/rockpaperscissors/rps-cv-images/scissors/sYwtAuLI5zLIEfJI.png
#   inflating: /content/drive/MyDrive/Playground/__MACOSX/rockpaperscissors/rps-cv-images/scissors/._sYwtAuLI5zLIEfJI.png
#   inflating: /content/drive/MyDrive/Playground/rockpaperscissors/rps-cv-images/scissors/s1gqGqCAbVLwDSw8.png
#   inflating: /content/drive/MyDrive/Playground/__MACOSX/rockpaperscissors/rps-cv-images/scissors/._s1gqGqCAbVLwDSw8.png

# %%
# Remove downloaded dataset
# !rm -rf rockpaperscissors.zip

# %% [markdown]
# ### Data Spliting

# %%
# Split dataset with 6:4 ratio 
splitfolders.ratio(
    os.path.join(BASE_PATH, 'rockpaperscissors/rps-cv-images'), 
    os.path.join(BASE_PATH, 'rockpaperscissors/data'), 
    seed=1, 
    ratio=(.6, .4)
)
# Out:
# Copying files: 0 files [00:00, ? files/s]
# Copying files: 1 files [00:00,  4.72 files/s]
# Copying files: 10 files [00:00,  6.59 files/s]
# Copying files: 18 files [00:00,  9.09 files/s]
# Copying files: 23 files [00:00, 11.16 files/s]
# Copying files: 31 files [00:00, 14.96 files/s]
# Copying files: 36 files [00:00, 18.18 files/s]
# Copying files: 45 files [00:00, 23.79 files/s]
# Copying files: 52 files [00:01, 29.63 files/s]
# Copying files: 59 files [00:01, 30.26 files/s]
# Copying files: 67 files [00:01, 36.81 files/s]
# Copying files: 73 files [00:01, 33.89 files/s]
# Copying files: 81 files [00:01, 40.91 files/s]
# Copying files: 88 files [00:01, 40.33 files/s]
# Copying files: 96 files [00:02, 46.95 files/s]
# Copying files: 105 files [00:02, 54.78 files/s]
# Copying files: 112 files [00:02, 44.33 files/s]
# Copying files: 120 files [00:02, 50.99 files/s]
# Copying files: 127 files [00:02, 41.81 files/s]
# Copying files: 135 files [00:02, 48.46 files/s]
# Copying files: 142 files [00:03, 41.19 files/s]
# Copying files: 152 files [00:03, 49.62 files/s]
# Copying files: 159 files [00:03, 40.86 files/s]
# Copying files: 1894 files [00:41, 38.42 files/s]
# Copying files: 1903 files [00:42, 46.25 files/s]
# Copying files: 1909 files [00:42, 37.76 files/s]
# Copying files: 1917 files [00:42, 44.10 files/s]
# Copying files: 1924 files [00:42, 44.15 files/s]
# Copying files: 1933 files [00:42, 51.76 files/s]
# Copying files: 1941 files [00:42, 45.73 files/s]
# Copying files: 1949 files [00:42, 52.23 files/s]
# Copying files: 1958 files [00:43, 46.53 files/s]
# Copying files: 1967 files [00:43, 54.06 files/s]
# Copying files: 1975 files [00:43, 49.19 files/s]
# Copying files: 1984 files [00:43, 56.00 files/s]
# Copying files: 1992 files [00:43, 46.39 files/s]
# Copying files: 2001 files [00:43, 53.82 files/s]
# Copying files: 2009 files [00:44, 45.35 files/s]
# Copying files: 2017 files [00:44, 51.57 files/s]
# Copying files: 2025 files [00:44, 57.24 files/s]
# Copying files: 2032 files [00:44, 54.24 files/s]
# Copying files: 2039 files [00:44, 41.15 files/s]
# Copying files: 2045 files [00:45, 35.92 files/s]
# Copying files: 2052 files [00:45, 41.91 files/s]
# Copying files: 2059 files [00:45, 37.88 files/s]
# Copying files: 2064 files [00:45, 30.64 files/s]
# Copying files: 2073 files [00:45, 37.87 files/s]
# Copying files: 2079 files [00:46, 24.27 files/s]
# Copying files: 2087 files [00:46, 30.42 files/s]
# Copying files: 2093 files [00:46, 29.78 files/s]
# Copying files: 2101 files [00:46, 25.98 files/s]
# Copying files: 2108 files [00:47, 27.32 files/s]
# Copying files: 2115 files [00:47, 32.99 files/s]
# Copying files: 2122 files [00:47, 39.03 files/s]
# Copying files: 2128 files [00:47, 40.69 files/s]
# Copying files: 2136 files [00:47, 47.70 files/s]
# Copying files: 2142 files [00:47, 39.27 files/s]
# Copying files: 2151 files [00:47, 46.96 files/s]
# Copying files: 2158 files [00:48, 25.71 files/s]
# Copying files: 2165 files [00:48, 31.71 files/s]
# Copying files: 2171 files [00:48, 31.50 files/s]
# Copying files: 2179 files [00:48, 38.48 files/s]
# Copying files: 2188 files [00:49, 44.31 files/s]

# %%
# Set dataset path
DATA_PATH = os.path.join(BASE_PATH, 'rockpaperscissors/data')
TRAIN_PATH = os.path.join(DATA_PATH, 'train')
VALIDATION_PATH = os.path.join(DATA_PATH, 'val')

# %%
# Check total train data
count_data(TRAIN_PATH)
# Out:
# paper : 428
# rock : 436
# scissors : 450
#
# Total data : 1314

# %%
# Check total validation data
count_data(VALIDATION_PATH)
# Out:
# paper : 284
# rock : 290
# scissors : 300
#
# Total data : 874

# %%
# Check dataset
images = []
filenames = glob.glob(os.path.join(TRAIN_PATH, 'paper') + '/*.png')[:5]
for filename in filenames:
  image = cv2.imread(filename)
  image = cv2.resize(image, (IMAGE_HEIGHT, IMAGE_WIDTH), interpolation = cv2.INTER_AREA)
  image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
  images.append(image)

# %%
plot_image(images)

# %% [markdown]
# ### Data Augmentation

# %%
data_generator = ImageDataGenerator(
  rescale=1./255,
  rotation_range=45,
  width_shift_range=.15,
  height_shift_range=.15,
  shear_range=.2,
  zoom_range=.2,
  horizontal_flip=True)

# %%
train_generator = data_generator.flow_from_directory(
  TRAIN_PATH,
  target_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
  batch_size=BATCH_SIZE,
  color_mode='rgb',
  class_mode='categorical',
  shuffle = True,
  seed=42)

validation_generator = data_generator.flow_from_directory(
  VALIDATION_PATH,
  target_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
  batch_size=BATCH_SIZE,
  color_mode='rgb',
  class_mode='categorical',
  shuffle = True,
  seed=42)
# Out:
# Found 1314 images belonging to 3 classes.
# Found 874 images belonging to 3 classes.

# %%
sample_train_images, _ = next(train_generator)
sample_validation_images, _ = next(validation_generator)

# %%
plot_image(sample_train_images)

# %%
plot_image(sample_validation_images)

# %% [markdown]
# ## Model

# %% [markdown]
# ### Simple CNN from Scratch

# %%
def CNN():
  model = Sequential()
  model.add(layers.Conv2D(8, (3, 3), padding='same', activation='relu', input_shape=(IMAGE_WIDTH, IMAGE_HEIGHT, 3)))
  model.add(layers.MaxPooling2D(2, 2))
  model.add(layers.Conv2D(32, (3,3), activation='relu'))
  model.add(layers.MaxPooling2D(2, 2))
  model.add(layers.Conv2D(64, (3,3), activation='relu'))
  model.add(layers.MaxPooling2D(2, 2))
  model.add(layers.Conv2D(128, (3,3), activation='relu'))
  model.add(layers.MaxPooling2D(2, 2))
  model.add(layers.Conv2D(128, (3,3), activation='relu'))
  model.add(layers.MaxPooling2D(2, 2))
  model.add(layers.Flatten())
  model.add(layers.Dense(512, activation='relu'))
  model.add(layers.Dense(NUM_CLASS, activation='softmax'))

  optimizer = Adam(LEARNING_RATE)
  model.compile(optimizer=optimizer,
                loss='categorical_crossentropy',
                metrics=['accuracy'])
  
  return model

# %%
# Visualize CNN model
plot_model(CNN(), to_file=os.path.join(BASE_PATH, 'visualization/CNN.png'), show_shapes=True)

# %% [markdown]
# ### VGG16 + CNN Transfer Learning

# %%
def VGGCNN():
  input_tensor = layers.Input(shape=(IMAGE_WIDTH, IMAGE_HEIGHT, 3))
  vgg16 = VGG16(
      weights='imagenet',
      include_top=False,
      input_tensor=input_tensor
  )
  
  # Make CNN layers not trainable / Freezing Convolutional layers
  # Don't train existing weights, because the weights are ready fix
  for layer in vgg16.layers:
      layer.trainable = False
        
  # Defreeze all batch normalization layers due to a bug in transfer learning using keras
  for layer in vgg16.layers:
      if "BatchNormalization" in layer.__class__.__name__:
          layer.trainable = True
  
  cnn = Sequential()
  cnn.add(layers.Flatten(input_shape=vgg16.output_shape[1:]))
  cnn.add(layers.Dense(512, activation='relu'))
  cnn.add(layers.Dropout(0.5))
  cnn.add(layers.Dense(NUM_CLASS, activation='softmax'))

  model = Model(vgg16.input, cnn(vgg16.output))

  optimizer = Adam(LEARNING_RATE)
  model.compile(optimizer=optimizer,
                loss='categorical_crossentropy',
                metrics=['accuracy'])
  
  return model

# %%
# Visualize Custom VGG16+CNN transfer learning model
plot_model(VGGCNN(), to_file=os.path.join(BASE_PATH, 'visualization/CNN.png'), show_shapes=True)

# %% [markdown]
# ## Training

# %% [markdown]
# ### Training using CNN Model

# %%
# Adding callbacks
train_id = 'cnn-' + str(uuid.uuid1())
best_model = os.path.join(BASE_PATH, 'model/best_model-' + train_id + '.h5')
last_model = os.path.join(BASE_PATH, 'model/last_model-' + train_id + '.h5')
csv_log = os.path.join(BASE_PATH, 'monitor/logs-' + train_id + '.h5')

ES = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)
MC = ModelCheckpoint(best_model, monitor='val_accuracy', mode='max', save_best_only=True, verbose=1)
CSVL = CSVLogger(csv_log, separator=",", append=True)

callbacks = [MC, ES, CSVL]

# %%
# Training start time
start_time = time.time()

print("Training strated with Train ID: {}".format(train_id))

model = CNN()
history = model.fit_generator(train_generator, 
                    steps_per_epoch=25, 
                    epochs=20, 
                    validation_data=validation_generator,
                    validation_steps=5,
                    verbose=1,
                    callbacks=callbacks)

# Training complete
time_elapsed = time.time() - start_time
# Save last model
model.save(last_model)

print("=" * 30)
print("Training Finished, took {:.0f}m {:.0f}s".format(time_elapsed // 60, time_elapsed % 60))
print("Best model:", best_model)
print("Last model:", last_model)

# Plot training and loss accuracy
plot_training(history, train_id)

# Load best model
print("Load best model to evaluate ...")
model = load_model(best_model)
model_evaluation(train_id, model, train_generator, validation_generator)
# Out:
# Training strated with Train ID: cnn-d4a8c2a0-dbab-11eb-955a-0242ac1c0002
# Epoch 1/20
# 25/25 [==============================] - 13s 498ms/step - loss: 1.1112 - accuracy: 0.3706 - val_loss: 1.0948 - val_accuracy: 0.3000
#
# Epoch 00001: val_accuracy improved from -inf to 0.30000, saving model to /content/drive/MyDrive/Playground/model/best_model-cnn-d4a8c2a0-dbab-11eb-955a-0242ac1c0002.h5
# Epoch 2/20
# 25/25 [==============================] - 12s 486ms/step - loss: 1.0590 - accuracy: 0.4124 - val_loss: 1.0426 - val_accuracy: 0.6500
#
# Epoch 00002: val_accuracy improved from 0.30000 to 0.65000, saving model to /content/drive/MyDrive/Playground/model/best_model-cnn-d4a8c2a0-dbab-11eb-955a-0242ac1c0002.h5
# Epoch 3/20
# 25/25 [==============================] - 12s 476ms/step - loss: 0.8718 - accuracy: 0.6391 - val_loss: 0.6360 - val_accuracy: 0.7312
#
# Epoch 00003: val_accuracy improved from 0.65000 to 0.73125, saving model to /content/drive/MyDrive/Playground/model/best_model-cnn-d4a8c2a0-dbab-11eb-955a-0242ac1c0002.h5
# Epoch 4/20
# 25/25 [==============================] - 12s 478ms/step - loss: 0.5869 - accuracy: 0.7687 - val_loss: 0.4765 - val_accuracy: 0.7937
#
# Epoch 00004: val_accuracy improved from 0.73125 to 0.79375, saving model to /content/drive/MyDrive/Playground/model/best_model-cnn-d4a8c2a0-dbab-11eb-955a-0242ac1c0002.h5
# Epoch 5/20
# 25/25 [==============================] - 12s 470ms/step - loss: 0.5061 - accuracy: 0.7987 - val_loss: 0.3881 - val_accuracy: 0.8750
#
# Epoch 00005: val_accuracy improved from 0.79375 to 0.87500, saving model to /content/drive/MyDrive/Playground/model/best_model-cnn-d4a8c2a0-dbab-11eb-955a-0242ac1c0002.h5
# Epoch 6/20
# 25/25 [==============================] - 12s 477ms/step - loss: 0.4371 - accuracy: 0.8069 - val_loss: 0.4167 - val_accuracy: 0.8375
#
# Epoch 00006: val_accuracy did not improve from 0.87500
# Epoch 7/20
# 25/25 [==============================] - 11s 458ms/step - loss: 0.3630 - accuracy: 0.8569 - val_loss: 0.3692 - val_accuracy: 0.8687
#
# Epoch 00007: val_accuracy did not improve from 0.87500
# Epoch 8/20
# 25/25 [==============================] - 12s 468ms/step - loss: 0.4016 - accuracy: 0.8497 - val_loss: 0.2822 - val_accuracy: 0.8625
#
# Epoch 00008: val_accuracy did not improve from 0.87500
# Epoch 9/20
# 25/25 [==============================] - 12s 470ms/step - loss: 0.2011 - accuracy: 0.9332 - val_loss: 0.1469 - val_accuracy: 0.9375
#
# Epoch 00009: val_accuracy improved from 0.87500 to 0.93750, saving model to /content/drive/MyDrive/Playground/model/best_model-cnn-d4a8c2a0-dbab-11eb-955a-0242ac1c0002.h5
# Epoch 10/20
# 25/25 [==============================] - 12s 482ms/step - loss: 0.1950 - accuracy: 0.9168 - val_loss: 0.1150 - val_accuracy: 0.9750
#
# Epoch 00010: val_accuracy improved from 0.93750 to 0.97500, saving model to /content/drive/MyDrive/Playground/model/best_model-cnn-d4a8c2a0-dbab-11eb-955a-0242ac1c0002.h5
# Epoch 11/20
# 25/25 [==============================] - 12s 486ms/step - loss: 0.1055 - accuracy: 0.9756 - val_loss: 0.1421 - val_accuracy: 0.9563
#
# Epoch 00011: val_accuracy did not improve from 0.97500
# Epoch 12/20
# 25/25 [==============================] - 11s 462ms/step - loss: 0.1603 - accuracy: 0.9431 - val_loss: 0.0782 - val_accuracy: 0.9750
#
# Epoch 00012: val_accuracy did not improve from 0.97500
# Epoch 13/20
# 25/25 [==============================] - 12s 478ms/step - loss: 0.1258 - accuracy: 0.9594 - val_loss: 0.0627 - val_accuracy: 0.9812
#
# Epoch 00013: val_accuracy improved from 0.97500 to 0.98125, saving model to /content/drive/MyDrive/Playground/model/best_model-cnn-d4a8c2a0-dbab-11eb-955a-0242ac1c0002.h5
# Epoch 14/20
# 25/25 [==============================] - 12s 466ms/step - loss: 0.2395 - accuracy: 0.9162 - val_loss: 0.1850 - val_accuracy: 0.9563
#
# Epoch 00014: val_accuracy did not improve from 0.98125
# Epoch 15/20
# 25/25 [==============================] - 12s 487ms/step - loss: 0.2056 - accuracy: 0.9335 - val_loss: 0.1125 - val_accuracy: 0.9625
#
# Epoch 00015: val_accuracy did not improve from 0.98125
# Epoch 16/20
# 25/25 [==============================] - 12s 467ms/step - loss: 0.0999 - accuracy: 0.9579 - val_loss: 0.0595 - val_accuracy: 0.9875
#
# Epoch 00016: val_accuracy improved from 0.98125 to 0.98750, saving model to /content/drive/MyDrive/Playground/model/best_model-cnn-d4a8c2a0-dbab-11eb-955a-0242ac1c0002.h5
# Epoch 17/20
# 25/25 [==============================] - 11s 455ms/step - loss: 0.0957 - accuracy: 0.9644 - val_loss: 0.0615 - val_accuracy: 0.9812
#
# Epoch 00017: val_accuracy did not improve from 0.98750
# Epoch 18/20
# 25/25 [==============================] - 11s 457ms/step - loss: 0.0942 - accuracy: 0.9688 - val_loss: 0.0653 - val_accuracy: 0.9937
#
# Epoch 00018: val_accuracy improved from 0.98750 to 0.99375, saving model to /content/drive/MyDrive/Playground/model/best_model-cnn-d4a8c2a0-dbab-11eb-955a-0242ac1c0002.h5
# Epoch 19/20
# 25/25 [==============================] - 12s 475ms/step - loss: 0.0728 - accuracy: 0.9714 - val_loss: 0.0467 - val_accuracy: 0.9812
#
# Epoch 00019: val_accuracy did not improve from 0.99375
# Epoch 20/20
# 25/25 [==============================] - 12s 474ms/step - loss: 0.0409 - accuracy: 0.9850 - val_loss: 0.0253 - val_accuracy: 0.9937
#
# Epoch 00020: val_accuracy did not improve from 0.99375
# ==============================
# Training Finished, took 5m 50s
# Best model: /content/drive/MyDrive/Playground/model/best_model-cnn-d4a8c2a0-dbab-11eb-955a-0242ac1c0002.h5
# Last model: /content/drive/MyDrive/Playground/model/last_model-cnn-d4a8c2a0-dbab-11eb-955a-0242ac1c0002.h5
# ### Training Loss and Accuracy
# Load best model to evaluate ...
# ### Training Accuracy
# 42/42 [==============================] - 16s 360ms/step - loss: 0.0701 - accuracy: 0.9711
# loss: 7.01
# acc: 97.11
# ### Validation Accuracy
# 28/28 [==============================] - 10s 357ms/step - loss: 0.0751 - accuracy: 0.9714
# loss: 7.51
# acc: 97.14
# ### Evaluation of Model Performance
# 28/28 [==============================] - 10s 362ms/step
# #### Confusion Matrix
# True Positive (TP): 86
# False Positive (FP): 94
# False Negative (FN): 78
# True Negative (TN): 106
# Calculated Accuracy: 52.74725274725275
# #### Classification Report
#               precision    recall  f1-score   support
#
#        paper       0.34      0.30      0.32       284
#         rock       0.34      0.37      0.35       290
#     scissors       0.32      0.32      0.32       300
#
#     accuracy                           0.33       874
#    macro avg       0.33      0.33      0.33       874
# weighted avg       0.33      0.33      0.33       874
#
# Accuracy: 0.33
#
# Macro Precision: 0.33
# Macro Recall: 0.33
# Macro F1-score: 0.33
#
# Weighted Precision: 0.33
# Weighted Recall: 0.33
# Weighted F1-score: 0.33

# %% [markdown]
# ### Training using VGG16 + CNN Model Transfer Learning

# %%
# Adding callbacks
train_id = 'vgg16-' + str(uuid.uuid1())
best_model = os.path.join(BASE_PATH, 'model/best_model-' + train_id + '.h5')
last_model = os.path.join(BASE_PATH, 'model/last_model-' + train_id + '.h5')
csv_log = os.path.join(BASE_PATH, 'monitor/logs-' + train_id + '.h5')

ES = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)
MC = ModelCheckpoint(best_model, monitor='val_accuracy', mode='max', save_best_only=True, verbose=1)
CSVL = CSVLogger(csv_log, separator=",", append=True)

callbacks = [MC, ES, CSVL]

# %%
# Training start time
start_time = time.time()

print("Training strated with Train ID: {}".format(train_id))

model = VGGCNN()
history = model.fit_generator(train_generator, 
                    steps_per_epoch=25, 
                    epochs=20, 
                    validation_data=validation_generator,
                    validation_steps=5,
                    verbose=1,
                    callbacks=callbacks)

# Training complete
time_elapsed = time.time() - start_time
# Save last model
model.save(last_model)

print("=" * 30)
print("Training Finished, took {:.0f}m {:.0f}s".format(time_elapsed // 60, time_elapsed % 60))
print("Best model:", best_model)
print("Last model:", last_model)

# Plot training and loss accuracy
plot_training(history, train_id)

# Load best model
print("Load best model to evaluate ...")
model = load_model(best_model)
model_evaluation(train_id, model, train_generator, validation_generator)
# Out:
# Training strated with Train ID: vgg16-d3827468-dbb3-11eb-955a-0242ac1c0002
# Epoch 1/20
# 25/25 [==============================] - 21s 531ms/step - loss: 3.4474 - accuracy: 0.5455 - val_loss: 0.2698 - val_accuracy: 0.9062
#
# Epoch 00001: val_accuracy improved from -inf to 0.90625, saving model to /content/drive/MyDrive/Playground/model/best_model-vgg16-d3827468-dbb3-11eb-955a-0242ac1c0002.h5
# Epoch 2/20
# 25/25 [==============================] - 13s 521ms/step - loss: 0.5164 - accuracy: 0.8120 - val_loss: 0.2130 - val_accuracy: 0.9250
#
# Epoch 00002: val_accuracy improved from 0.90625 to 0.92500, saving model to /content/drive/MyDrive/Playground/model/best_model-vgg16-d3827468-dbb3-11eb-955a-0242ac1c0002.h5
# Epoch 3/20
# 25/25 [==============================] - 13s 523ms/step - loss: 0.1618 - accuracy: 0.9433 - val_loss: 0.1216 - val_accuracy: 0.9812
#
# Epoch 00003: val_accuracy improved from 0.92500 to 0.98125, saving model to /content/drive/MyDrive/Playground/model/best_model-vgg16-d3827468-dbb3-11eb-955a-0242ac1c0002.h5
# Epoch 4/20
# 25/25 [==============================] - 13s 528ms/step - loss: 0.1675 - accuracy: 0.9428 - val_loss: 0.0879 - val_accuracy: 0.9750
#
# Epoch 00004: val_accuracy did not improve from 0.98125
# Epoch 5/20
# 25/25 [==============================] - 13s 503ms/step - loss: 0.1495 - accuracy: 0.9479 - val_loss: 0.1284 - val_accuracy: 0.9563
#
# Epoch 00005: val_accuracy did not improve from 0.98125
# Epoch 6/20
# 25/25 [==============================] - 13s 502ms/step - loss: 0.1474 - accuracy: 0.9575 - val_loss: 0.0543 - val_accuracy: 0.9688
#
# Epoch 00006: val_accuracy did not improve from 0.98125
# Epoch 7/20
# 25/25 [==============================] - 13s 513ms/step - loss: 0.1115 - accuracy: 0.9604 - val_loss: 0.0353 - val_accuracy: 0.9875
#
# Epoch 00007: val_accuracy improved from 0.98125 to 0.98750, saving model to /content/drive/MyDrive/Playground/model/best_model-vgg16-d3827468-dbb3-11eb-955a-0242ac1c0002.h5
# Epoch 8/20
# 25/25 [==============================] - 13s 523ms/step - loss: 0.1058 - accuracy: 0.9584 - val_loss: 0.0254 - val_accuracy: 1.0000
#
# Epoch 00008: val_accuracy improved from 0.98750 to 1.00000, saving model to /content/drive/MyDrive/Playground/model/best_model-vgg16-d3827468-dbb3-11eb-955a-0242ac1c0002.h5
# Epoch 9/20
# 25/25 [==============================] - 13s 535ms/step - loss: 0.1393 - accuracy: 0.9330 - val_loss: 0.0772 - val_accuracy: 0.9688
#
# Epoch 00009: val_accuracy did not improve from 1.00000
# Epoch 10/20
# 25/25 [==============================] - 13s 509ms/step - loss: 0.0975 - accuracy: 0.9701 - val_loss: 0.1208 - val_accuracy: 0.9500
#
# Epoch 00010: val_accuracy did not improve from 1.00000
# Epoch 11/20
# 25/25 [==============================] - 13s 499ms/step - loss: 0.1150 - accuracy: 0.9647 - val_loss: 0.0278 - val_accuracy: 0.9937
#
# Epoch 00011: val_accuracy did not improve from 1.00000
# Epoch 12/20
# 25/25 [==============================] - 12s 487ms/step - loss: 0.0894 - accuracy: 0.9687 - val_loss: 0.0454 - val_accuracy: 0.9937
#
# Epoch 00012: val_accuracy did not improve from 1.00000
# Epoch 13/20
# 25/25 [==============================] - 13s 508ms/step - loss: 0.0826 - accuracy: 0.9703 - val_loss: 0.0608 - val_accuracy: 0.9750
#
# Epoch 00013: val_accuracy did not improve from 1.00000
# Epoch 14/20
# 25/25 [==============================] - 12s 493ms/step - loss: 0.0965 - accuracy: 0.9660 - val_loss: 0.1066 - val_accuracy: 0.9438
#
# Epoch 00014: val_accuracy did not improve from 1.00000
# Epoch 15/20
# 25/25 [==============================] - 12s 493ms/step - loss: 0.1319 - accuracy: 0.9602 - val_loss: 0.0390 - val_accuracy: 0.9875
#
# Epoch 00015: val_accuracy did not improve from 1.00000
# Epoch 16/20
# 25/25 [==============================] - 13s 501ms/step - loss: 0.0707 - accuracy: 0.9771 - val_loss: 0.0215 - val_accuracy: 0.9937
#
# Epoch 00016: val_accuracy did not improve from 1.00000
# Epoch 17/20
# 25/25 [==============================] - 13s 503ms/step - loss: 0.1067 - accuracy: 0.9695 - val_loss: 0.0280 - val_accuracy: 0.9937
#
# Epoch 00017: val_accuracy did not improve from 1.00000
# Epoch 18/20
# 25/25 [==============================] - 12s 492ms/step - loss: 0.0940 - accuracy: 0.9654 - val_loss: 0.0376 - val_accuracy: 0.9937
#
# Epoch 00018: val_accuracy did not improve from 1.00000
# Epoch 19/20
# 25/25 [==============================] - 12s 490ms/step - loss: 0.0614 - accuracy: 0.9805 - val_loss: 0.0536 - val_accuracy: 0.9875
#
# Epoch 00019: val_accuracy did not improve from 1.00000
# Epoch 20/20
# 25/25 [==============================] - 12s 490ms/step - loss: 0.0798 - accuracy: 0.9700 - val_loss: 0.0342 - val_accuracy: 0.9875
#
# Epoch 00020: val_accuracy did not improve from 1.00000
# ==============================
# Training Finished, took 6m 40s
# Best model: /content/drive/MyDrive/Playground/model/best_model-vgg16-d3827468-dbb3-11eb-955a-0242ac1c0002.h5
# Last model: /content/drive/MyDrive/Playground/model/last_model-vgg16-d3827468-dbb3-11eb-955a-0242ac1c0002.h5
# ### Training Loss and Accuracy
# Load best model to evaluate ...
# ### Training Accuracy
# 42/42 [==============================] - 18s 400ms/step - loss: 0.0651 - accuracy: 0.9779
# loss: 6.51
# acc: 97.79
# ### Validation Accuracy
# 28/28 [==============================] - 13s 476ms/step - loss: 0.0707 - accuracy: 0.9794
# loss: 7.07
# acc: 97.94
# ### Evaluation of Model Performance
# 28/28 [==============================] - 11s 397ms/step
# #### Confusion Matrix
# True Positive (TP): 91
# False Positive (FP): 86
# False Negative (FN): 90
# True Negative (TN): 100
# Calculated Accuracy: 52.043596730245234
# #### Classification Report
#               precision    recall  f1-score   support
#
#        paper       0.33      0.32      0.33       284
#         rock       0.34      0.34      0.34       290
#     scissors       0.33      0.35      0.34       300
#
#     accuracy                           0.34       874
#    macro avg       0.34      0.34      0.34       874
# weighted avg       0.34      0.34      0.34       874
#
# Accuracy: 0.34
#
# Macro Precision: 0.34
# Macro Recall: 0.34
# Macro F1-score: 0.34
#
# Weighted Precision: 0.34
# Weighted Recall: 0.34
# Weighted F1-score: 0.34

# %% [markdown]
# ## Make Prediction

# %%
def prediction(model_path):
  # Load model
  model = load_model(model_path)
  # Start uploading
  upload = files.upload()
  for path in upload.keys():
    # predicting uploaded image
    img = image.load_img(path, target_size=(IMAGE_WIDTH, IMAGE_HEIGHT))

    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)

    images = np.vstack([x])
    classes = model.predict(images, batch_size=BATCH_SIZE)

    if classes[0,0] != 0:
      label = 'PAPER'
    elif classes[0,1] != 0:
      label = 'ROCK'
    else:
      label = 'SCISSORS'

    # ploting the image
    plt.title("Prediction : {}".format(label))
    plt.imshow(img)

# %%
# List available model
# Model using CNN from Scratch
cnn_best_model = '/content/drive/MyDrive/Playground/model/best_model-cnn-d4a8c2a0-dbab-11eb-955a-0242ac1c0002.h5'
cnn_last_model = '/content/drive/MyDrive/Playground/model/last_model-cnn-d4a8c2a0-dbab-11eb-955a-0242ac1c0002.h5'
# Model using VGG16 + CNN Transfer Learning
vgg16_best_model = '/content/drive/MyDrive/Playground/model/best_model-vgg16-d3827468-dbb3-11eb-955a-0242ac1c0002.h5'
vgg16_last_model = '/content/drive/MyDrive/Playground/model/last_model-vgg16-d3827468-dbb3-11eb-955a-0242ac1c0002.h5'

# %%
# Make prediction, show upload page to predict using CNN from Scratch
prediction(model_path=cnn_best_model)
# Out:
#      <input type="file" id="files-1816748b-5bd0-460d-b62f-c3713ddf9f99" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1816748b-5bd0-460d-b62f-c3713ddf9f99">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 0eqArS2GgsBeqgSn.png to 0eqArS2GgsBeqgSn (4).png

# %%
# Make prediction, show upload page to predict using VGG16 + CNN Transfer Learning
prediction(model_path=vgg16_best_model)
# Out:
#      <input type="file" id="files-f72039a3-eea9-4176-b29e-3e1809f331d1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f72039a3-eea9-4176-b29e-3e1809f331d1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 2f25VA1nfxiC86xj.png to 2f25VA1nfxiC86xj.png
# WARNING:tensorflow:6 out of the last 33 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f473a7f17a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
